# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("Scikit-learn Version:", sklearn.__version__)
# Out:
# NumPy Version: 2.3.5
# Pandas Version: 2.3.3
# Scikit-learn Version: 1.7.2

# %%
x=0
y="YOKOSU WATASHINO SOUL SOCIETY"
z="yare yare"
print(x)
print(y)
print(z)
# Out:
# 0
# YOKOSU WATASHINO SOUL SOCIETY
# yare yare

# %%
x=10;
y="BANKAI"
z=5.5
print("Value of x: ",x)
print("Value of y: ",y)
print("Value of z: ",z)
print("Data types:\n")
print(type(x))
print(type(y))
print(type(z))
# Out:
# Value of x:  10
# Value of y:  BANKAI
# Value of z:  5.5
# Data types:
#
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
x=float(input())
y=int(input())
print(x+y)
# Out:
#  12.5
#  4
# 16.5

# %%
name=input("Enter name:")
print("Hello,",name)
print("WELCOME")
# Out:
# Enter name: hi
# Hello, hi
# WELCOME

# %%
if 2>10:
    print("greater")
else:
    print("Smaller")
# Out:
# Smaller
