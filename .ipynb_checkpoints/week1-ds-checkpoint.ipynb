# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
import numpy as np
a = np.array([10,20,30,40])
print(a)
# Out:
# [10 20 30 40]

# %%
import pandas as pd

data = {
    "Name": ["Ram","Sita","John"],
    "Age": [20,21,22]
}

df = pd.DataFrame(data)
df
# Out:
#    Name  Age
# 0   Ram   20
# 1  Sita   21
# 2  John   22

# %%
import matplotlib.pyplot as plt

x = [1,2,4]
y = [10,20,40]

plt.plot(x,y)
plt.show()
